# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import tensorflow as tf

# %%
DF = pd.read_csv('train.csv')
DF.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2522922      11.135007     B        C4            MORTGAGE  ...
# 1     BAT1586599      12.237563     C        D3                RENT  ...
# 2     BAT2136391      12.545884     F        D4            MORTGAGE  ...
# 3     BAT2428731      16.731201     C        C3            MORTGAGE  ...
# 4     BAT5341619      15.008300     C        D4            MORTGAGE  ...
#
#     Recoveries Collection Recovery Fee Collection 12 months Medical  \
# ...

# %%
DF.describe()
# Out:
#                  ID   Loan Amount  Funded Amount  Funded Amount Investor  \
# count  6.746300e+04  67463.000000   67463.000000            67463.000000
# mean   2.562761e+07  16848.902776   15770.599114            14621.799323
# std    2.109155e+07   8367.865726    8150.992662             6785.345170
# min    1.297933e+06   1014.000000    1014.000000             1114.590204
# 25%    6.570288e+06  10012.000000    9266.500000             9831.684984
# 50%    1.791565e+07  16073.000000   13042.000000            12793.682170
# 75%    4.271521e+07  22106.000000   21793.000000            17807.594120
# max    7.224578e+07  35000.000000   34999.000000            34999.746430
#
#                Term  Interest Rate  Home Ownership  Debit to Income  \
# count  67463.000000   67463.000000    67463.000000     67463.000000
# mean      58.173814      11.846258    80541.502522        23.299241
# std        3.327441       3.718629    45029.120366         8.451824
# ...

# %%
df = DF[['ID','Loan Amount']]

# %%
df.head()
# Out:
#          ID  Loan Amount
# 0  65087372        10000
# 1   1450153         3609
# 2   1969101        28276
# 3   6651430        11170
# 4  14354669        16890

# %%
DF.at[104,'ID']
# Out:
# 14520277

# %%
DF.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2522922      11.135007     B        C4            MORTGAGE  ...
# 1     BAT1586599      12.237563     C        D3                RENT  ...
# 2     BAT2136391      12.545884     F        D4            MORTGAGE  ...
# 3     BAT2428731      16.731201     C        C3            MORTGAGE  ...
# 4     BAT5341619      15.008300     C        D4            MORTGAGE  ...
#
#     Recoveries Collection Recovery Fee Collection 12 months Medical  \
# ...

# %%
DF.drop(columns = ['Grade'],inplace=True)

# %%
DF.drop(columns = ['Sub Grade'],inplace=True)

# %%
DF.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Employment Duration  Home Ownership  \
# 0     BAT2522922      11.135007            MORTGAGE    176346.62670
# 1     BAT1586599      12.237563                RENT     39833.92100
# 2     BAT2136391      12.545884            MORTGAGE     91506.69105
# 3     BAT2428731      16.731201            MORTGAGE    108286.57590
# 4     BAT5341619      15.008300            MORTGAGE     44234.82545
#
#   Verification Status  ...   Recoveries Collection Recovery Fee  \
# 0        Not Verified  ...     2.498291                0.793724
# ...

# %%
DF.drop(columns = ['ID'],inplace=True)

# %%
DF.drop(columns = ['Payment Plan'],inplace=True)

# %%
DF = DF.rename(columns={'Employment Duration' : 'Ownership Type'})

# %%
key = {'w':1 ,'f':0}
DF.replace({'Initial List Status':key})
# Out:
#        Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0            10000          32236             12329.36286    59
# 1             3609          11940             12191.99692    59
# 2            28276           9311             21603.22455    59
# 3            11170           6954             17877.15585    59
# 4            16890          13226             13539.92667    59
# ...            ...            ...                     ...   ...
# 67458        13601           6848             13175.28583    59
# 67459         8323          11046             15637.46301    59
# 67460        15897          32921             12329.45775    59
# 67461        16567           4975             21353.68465    59
# 67462        15353          29875             14207.44860    59
#
#       Batch Enrolled  Interest Rate Ownership Type  Home Ownership  \
# 0         BAT2522922      11.135007       MORTGAGE    176346.62670
# ...

# %%
DF['Initial List Status'].head()
# Out:
# 0    w
# 1    f
# 2    w
# 3    w
# 4    w
# Name: Initial List Status, dtype: object

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67463 entries, 0 to 67462
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan Amount                   67463 non-null  int64
#  1   Funded Amount                 67463 non-null  int64
#  2   Funded Amount Investor        67463 non-null  float64
#  3   Term                          67463 non-null  int64
#  4   Batch Enrolled                67463 non-null  object
#  5   Interest Rate                 67463 non-null  float64
#  6   Ownership Type                67463 non-null  object
#  7   Home Ownership                67463 non-null  float64
#  8   Verification Status           67463 non-null  object
#  9   Loan Title                    67463 non-null  object
#  10  Debit to Income               67463 non-null  float64
#  11  Delinquency - two years       67463 non-null  int64
# ...

# %%
DF.isnull()
# Out:
#        Loan Amount  Funded Amount  Funded Amount Investor   Term  \
# 0            False          False                   False  False
# 1            False          False                   False  False
# 2            False          False                   False  False
# 3            False          False                   False  False
# 4            False          False                   False  False
# ...            ...            ...                     ...    ...
# 67458        False          False                   False  False
# 67459        False          False                   False  False
# 67460        False          False                   False  False
# 67461        False          False                   False  False
# 67462        False          False                   False  False
#
#        Batch Enrolled  Interest Rate  Ownership Type  Home Ownership  \
# 0               False          False           False           False
# ...

# %%
# prompt: drop last row of table

DF.drop(DF.tail(1).index, inplace=True)

# %%
DF.head()
# Out:
#    Loan Amount  Funded Amount  Funded Amount Investor  Term Batch Enrolled  \
# 0        10000          32236             12329.36286    59     BAT2522922
# 1         3609          11940             12191.99692    59     BAT1586599
# 2        28276           9311             21603.22455    59     BAT2136391
# 3        11170           6954             17877.15585    59     BAT2428731
# 4        16890          13226             13539.92667    59     BAT5341619
#
#    Interest Rate Ownership Type  Home Ownership Verification Status  \
# 0      11.135007       MORTGAGE    176346.62670        Not Verified
# 1      12.237563           RENT     39833.92100     Source Verified
# 2      12.545884       MORTGAGE     91506.69105     Source Verified
# 3      16.731201       MORTGAGE    108286.57590     Source Verified
# 4      15.008300       MORTGAGE     44234.82545     Source Verified
#
#                 Loan Title  ...   Recoveries  Collection Recovery Fee  \
# ...

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67462 entries, 0 to 67461
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan Amount                   67462 non-null  int64
#  1   Funded Amount                 67462 non-null  int64
#  2   Funded Amount Investor        67462 non-null  float64
#  3   Term                          67462 non-null  int64
#  4   Batch Enrolled                67462 non-null  object
#  5   Interest Rate                 67462 non-null  float64
#  6   Ownership Type                67462 non-null  object
#  7   Home Ownership                67462 non-null  float64
#  8   Verification Status           67462 non-null  object
#  9   Loan Title                    67462 non-null  object
#  10  Debit to Income               67462 non-null  float64
#  11  Delinquency - two years       67462 non-null  int64
# ...

# %%
def categorize_loan(input_term):
    categories = {
        "Home Loans": [
            "home loan", "home buying", "home improvement", "home", "pool", "bathroom",
            "nri home loans", "loan against property",
            "home improvement loan"
        ],    
        "Personal Loans": [
            "personal", "personal loan",
            "Loan", "Loan1", "Get debt free",
            "Pay off", "My Loan"
        ],
        "Debt Consolidation": [
            "debt consolidation", "bill consolidation",
            "debt free", "get out of debt", "debt reduction",
            "Bill Payoff", 
            "Debt Payoff", "Consolidation Loan", "debt loan", "Freedom", "debt",
             "Debt Consolidation Loan",
        ],
        "Credit Card Management": [
            "credit cards", "cc", "credit card payoff",
            "credit card refinance", "credit payoff", "credit cards","credit","card",
            "credit card refinance loan","credit card debt", "credit card loan",
            "Credit consolidation", "CC refinance", "CC consolidation"
            
        ],
        "Vehicle Loans": [
            "car loan", "car financing", "vehicle loans", "major purchase", 
            
        ],
        "Business Loans": [
            "business", "working capital loans", "small industry", "trade credit", 
            "lending club", "lending loan"
        ],
        "Education Loans": [
            "education loans"
        ],
        "Secured Loans": [
            "loan against property", "loan against securities", "gold loan", "loan against ppf"
        ],
        "Special Purpose Loans": [
            "wedding loan", "vacation", "travel loans", "medical expenses", "medical loan",
            "moving and relocation", "consumer durable loans"
        ],
        "Agriculture Loans": [
            "agriculture","green loans"
        ],
        "Other Financial Products": [
            "overdraft", "cash advances", "title loans", "Bills","Lending Club", "My Loan" ,"Pay Off","Refinance","Refinance Loan"
        ]
    }

    input_term = input_term.lower()
    for category, terms in categories.items():
        if any(term in input_term for term in terms):
            return category
    
    return "Uncategorized"

def main():
    print("Welcome to the Loan Category Classifier!")
    print("Enter a loan term, and I'll categorize it for you.")
    print("Type 'quit' to exit the program.")
    print()

    while True:
        user_input = input("Enter a loan term: ")
        if user_input.lower() == 'quit':
            print("Thank you for using the Loan Category Classifier. Goodbye!")
            break
        category = categorize_loan(user_input)
        print(f"Category: {category}")
        print()

if __name__ == "__main__":
    main()

set(DF['Loan Title'])
# Out:
# Welcome to the Loan Category Classifier!
# Enter a loan term, and I'll categorize it for you.
# Type 'quit' to exit the program.
# Enter a loan term:  quit
# Thank you for using the Loan Category Classifier. Goodbye!
# {'Bathroom',
#  'Bill Consolidation',
#  'Bill Payoff',
#  'Business',
#  'CC',
#  'CC Consolidation',
#  'CC Loan',
#  'CC Refi',
#  'CC Refinance',
#  'CC consolidation',
#  'CC-Refinance',
#  'CONSOLIDATE',
#  'CONSOLIDATION',
#  'Car Loan',
#  'Car financing',
#  'Card Consolidation',
#  'Cards',
#  'Consolidate',
#  'Consolidated',
#  'Consolidation',
#  'Consolidation Loan',
#  'Credit',
#  'Credit Card',
#  'Credit Card Consolidation',
#  'Credit Card Debt',
#  'Credit Card Loan',
#  'Credit Card Paydown',
#  'Credit Card Payoff',
#  'Credit Card Refi',
#  'Credit Card Refinance',
#  'Credit Card Refinance Loan',
#  'Credit Card consolidation',
#  'Credit Cards',
#  'Credit Consolidation',
#  'Credit Loan',
#  'Credit card pay off',
#  'Credit card payoff',
# ...

# %%
DF['Loan Title']
# Out:
# 0             Debt Consolidation
# 1             Debt consolidation
# 2             Debt Consolidation
# 3             Debt consolidation
# 4        Credit card refinancing
#                   ...
# 67457         Debt consolidation
# 67458    Credit card refinancing
# 67459    Credit card refinancing
# 67460               Lending loan
# 67461         Debt consolidation
# Name: Loan Title, Length: 67462, dtype: object

# %%
key = {'w':1,'f':0}
DF['Initial List Status'] = DF['Initial List Status'].map(key)

# %%
DF['Initial List Status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 67458    1
# 67459    1
# 67460    1
# 67461    0
# 67462    0
# Name: Initial List Status, Length: 67463, dtype: int64

# %%
DF.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2522922      11.135007     B        C4            MORTGAGE  ...
# 1     BAT1586599      12.237563     C        D3                RENT  ...
# 2     BAT2136391      12.545884     F        D4            MORTGAGE  ...
# 3     BAT2428731      16.731201     C        C3            MORTGAGE  ...
# 4     BAT5341619      15.008300     C        D4            MORTGAGE  ...
#
#     Recoveries Collection Recovery Fee Collection 12 months Medical  \
# ...

# %%
DF.drop(columns = ['Grade'],inplace=True)

# %%
DF.drop(columns = ['Sub Grade'],inplace=True)

# %%
DF.drop(columns = ['ID'],inplace=True)

# %%
DF = DF.rename(columns={'Employment Duration' : 'Ownership Type'})

# %%
DF.head()
# Out:
#    Loan Amount  Funded Amount  Funded Amount Investor  Term Batch Enrolled  \
# 0        10000          32236             12329.36286    59     BAT2522922
# 1         3609          11940             12191.99692    59     BAT1586599
# 2        28276           9311             21603.22455    59     BAT2136391
# 3        11170           6954             17877.15585    59     BAT2428731
# 4        16890          13226             13539.92667    59     BAT5341619
#
#    Interest Rate Ownership Type  Home Ownership Verification Status  \
# 0      11.135007       MORTGAGE    176346.62670        Not Verified
# 1      12.237563           RENT     39833.92100     Source Verified
# 2      12.545884       MORTGAGE     91506.69105     Source Verified
# 3      16.731201       MORTGAGE    108286.57590     Source Verified
# 4      15.008300       MORTGAGE     44234.82545     Source Verified
#
#   Payment Plan  ...   Recoveries  Collection Recovery Fee  \
# ...

# %%
DF.drop(columns = ['Payment Plan'],inplace=True)

# %%
DF.head()
# Out:
#    Loan Amount  Funded Amount  Funded Amount Investor  Term Batch Enrolled  \
# 0        10000          32236             12329.36286    59     BAT2522922
# 1         3609          11940             12191.99692    59     BAT1586599
# 2        28276           9311             21603.22455    59     BAT2136391
# 3        11170           6954             17877.15585    59     BAT2428731
# 4        16890          13226             13539.92667    59     BAT5341619
#
#    Interest Rate Ownership Type  Home Ownership Verification Status  \
# 0      11.135007       MORTGAGE    176346.62670        Not Verified
# 1      12.237563           RENT     39833.92100     Source Verified
# 2      12.545884       MORTGAGE     91506.69105     Source Verified
# 3      16.731201       MORTGAGE    108286.57590     Source Verified
# 4      15.008300       MORTGAGE     44234.82545     Source Verified
#
#                 Loan Title  ...   Recoveries  Collection Recovery Fee  \
# ...

# %%
DF['Initial List Status']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 67458    1
# 67459    1
# 67460    1
# 67461    0
# 67462    0
# Name: Initial List Status, Length: 67463, dtype: int64
